# %% [markdown]
# # HUF/USD End-to-End Calibration
# Reusable reference workflow notebook.

# %%
import numpy as np
from src.curves.parametric import fit_parametric_curve

# %%
tenors = np.array([0.25,0.5,1,2,3,5,7,10])
yields = np.array([0.068,0.067,0.066,0.064,0.063,0.062,0.0615,0.061])
liquidity = np.array([0.9,0.95,1.0,1.0,0.8,0.7,0.6,0.5])
result = fit_parametric_curve(tenors, yields, model='svensson', weight_mode='liquidity', liquidity=liquidity)
result
